# %%
import pandas as pd
import numpy as np
import scipy as sp
import plotly.plotly as py
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")

# %%
df.head()
df.describe()
plt.bar(df['School'],df['Gap'],0.2)
# Out:
# <Container object of 21 artists>

# %%
plt.bar(df['School'],df['Men'],0.2)
# Out:
# <Container object of 21 artists>

# %%
df['Men'].hist()

# %%
df['Women'].hist()

# %%
bins = np.linspace(40000, 200000, 100000)

plt.hist(df['Women'], bins, alpha=0.5, label='x')
plt.hist(df['Men'], bins, alpha=0.5, label='y')
plt.legend(loc='upper right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-c2738bb26050> in <module>()
#       1 bins = np.linspace(40000, 200000, 100000)
#       2
# ----> 3 plt.hist(df['Women'], bins, alpha=0.5, label='x')
#       4 plt.hist(df['Men'], bins, alpha=0.5, label='y')
#       5 plt.legend(loc='upper right')
#
# /usr/local/lib/python3.6/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, hold, data, **kwargs)
#    3023                       histtype=histtype, align=align, orientation=orientation,
#    3024                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3025                       stacked=stacked, normed=normed, data=data, **kwargs)
#    3026     finally:
#    3027         ax._hold = washold
#
# ...

# %%
np.linspace(40000, 200000, 100000)
bins = np.linspace(40000, 200000, 100000)

plt.hist(df['Women'], bins, alpha=0.5, label='x')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-4b647e765cc0> in <module>()
#       2 bins = np.linspace(40000, 200000, 100000)
#       3
# ----> 4 plt.hist(df['Women'], bins, alpha=0.5, label='x')
#
# /usr/local/lib/python3.6/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, hold, data, **kwargs)
#    3023                       histtype=histtype, align=align, orientation=orientation,
#    3024                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3025                       stacked=stacked, normed=normed, data=data, **kwargs)
#    3026     finally:
#    3027         ax._hold = washold
#
# /usr/local/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
# ...

# %%
x = [random.gauss(3,1) for _ in range(400)]
print(x)
